# %%
import requests
from IPython.core.display import HTML
HTML(f"""
<style>
@import "https://cdn.jsdelivr.net/npm/bulma@0.9.4/css/bulma.min.css";
</style>
""")

# %% [markdown]
# # Pen and paper exercises
# These exercises should be completed using only pen and paper.
#
# ---
# **Task 1 (easy): Smallest vector space**
# Suppose $\mathbf{P}$ is a plane through $(0, 0, 0)$ and $\mathbf{L}$ is a line
# through $(0, 0, 0)$. The smallest vector space containing both $\mathbf{P}$ and
# $\mathbf{L}$ is either $\mathbf(P)$ if the line lies on the plane or $\R^3$ otherwise.
#
# ---
# ---
# **Task 2 (medium): Solutions**
# For which vectors $(b_1, b_2, b_3)$ do these systems have a solution?
#
# $$
# a)\quad \begin{bmatrix}
# 1 & 1 & 1\\
# 0 & 1 & 1\\
# 0 & 0 & 1\\
# \end{bmatrix}
# \begin{bmatrix}
# x_1\\
# x_2\\
# x_3\\
# \end{bmatrix}
# =
# \begin{bmatrix}
# b_1\\
# b_2\\
# b_3\\
# \end{bmatrix}
# $$
#
# $$
# b)\quad \begin{bmatrix}
# 1 & 1 & 1\\
# 0 & 1 & 1\\
# 0 & 0 & 0\\
# \end{bmatrix}
# \begin{bmatrix}
# x_1\\
# x_2\\
# x_3\\
# \end{bmatrix}
# =
# \begin{bmatrix}
# b_1\\
# b_2\\
# b_3\\
# \end{bmatrix}
# $$
#
# $$
# c)\quad \begin{bmatrix}
# 1 & 1 & 1\\
# 0 & 0 & 1\\
# 0 & 0 & 1\\
# \end{bmatrix}
# \begin{bmatrix}
# x_1\\
# x_2\\
# x_3\\
# \end{bmatrix}
# =
# \begin{bmatrix}
# b_1\\
# b_2\\
# b_3\\
# \end{bmatrix}
# $$
#
# **Answer**:
#
# The solution vector is $(b_1, 0, 0)$. The reason for that is equation b and c 0'fies the $b_2$ and $b_3$ value. So in order for them all to have a vector that they share then
# that is the solution. That results in vector $(x_1, x_2, x_3)$ to have look the same as the vector with b's
#
# ---
# ---
# **Task 3 (medium): True or false**
# True or false (with a counterexample if false):
# 1. The vectors $\mathbf{b}$ that are not in the column space $\mathbf{C}(A)$
# form a subspace.
# 2. If $\mathbf{C}(A)$ contains only the zero vector, then $A$ is the zero matrix.
# 3. The column space of $2A$ equals the column space of $A$.
# 4. The column space of $A-I$ equals the column space of $A$ (test this).
#
#
# ---

# %% [markdown]
# 1. this is false since how can something that is not a column vector be a subspace of the column space
# 2. True
# 3. True, since the space of a is all the linear combinations of $A$. And $2A$ is a creating a linear combination
# 4. False. subtracting one of only some elements doesn't create a matrix that we can create with a linear combination
