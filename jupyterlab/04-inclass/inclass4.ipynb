# %%
import requests
from IPython.core.display import HTML
HTML(f"""
<style>
@import "https://cdn.jsdelivr.net/npm/bulma@0.9.4/css/bulma.min.css";
</style>
""")

# %% [markdown]
# # In-class Exercises 4
# The following exercise sheet is intended for in-class exercises. There may be more exercises that you have time for during the exercises. The intention is not necessarily that you should do all of them but mainly to be able to get a grasp of the content. However we always recommend that you do as many as you have time for (also outside exercises and lectures if you have time to do so).
# ### 1. Polynomial regression
# The following exercises are aimed at giving you an introduction to n-th order polynomial regressions. One of the learning goals with this exercise is to make you think about how some of the previously examined concepts (desing matrices, model parameters, regression line/curve) change in the context of a polynomial regression.
# **1) How many points are needed to fit a second order polynomial regression?**
# A. 1
# B. 2
# C. 3
# D. 4
# **2) Suppose we have a dataset with one predictor variable, $x$, and one response variable, $y$. We want to fit a 2nd order polynomial regression model of the form $y = \beta_0 + \beta_1 x + \beta_2 x^2 + \epsilon$ to the data. Which of the following design matrices could be used to estimate the regression coefficients?**
# A) $\begin{bmatrix}1 & x_1 \\
# 1 & x_2 \\
# 1 & x_3 \\
# \vdots & \vdots \\
# 1 & x_n  \end{bmatrix}$
# B) $\begin{bmatrix}1 & x_1 & x_1^2 & x_1^3 \\
# 1 & x_2 & x_2^2 & x_2^3 \\
# 1 & x_3 & x_3^2 & x_3^3 \\
# \vdots & \vdots & \vdots & \vdots \\
# 1 & x_n & x_n^2 & x_n^3 \end{bmatrix}$
# C) $\begin{bmatrix}x_1 & x_1^2 \\
# x_2 & x_2^2 \\
# x_3 & x_3^2  \\
# \vdots & \vdots \\
# x_n & x_n^2 \end{bmatrix}$
# D) $\begin{bmatrix}1 & x_1 & x_1^2 \\
# 1 & x_2 & x_2^2 \\
# 1 & x_3 & x_3^2  \\
# \vdots & \vdots \\
# 1 & x_n & x_n^2 \end{bmatrix}$
# **3) How many points are needed to fit a third order polynomial regression?**
# A. 1
# B. 2
# C. 3
# D. 4
# **4) Suppose we have a dataset with one predictor variable, $x$, and one response variable, $y$. We want to fit a 4th order polynomial regression model of the form $y = \beta_0 + \beta_1 x + \beta_2 x^2 + \beta_3 x^3 + \beta_4 x^4 + \epsilon$ to the data. Which of the following design matrices could be used to estimate the regression coefficients?**
# A) $\begin{bmatrix}1 & x_1 & x_1^2 & x_1^3 & x_1^4 \\
# 1 & x_2 & x_2^2 & x_2^3 & x_2^4 \\
# 1 & x_3 & x_3^2 & x_3^3 & x_3^4 \\
# \vdots & \vdots & \vdots & \vdots & \vdots \\
# 1 & x_n & x_n^2 & x_n^3 & x_n^4 \end{bmatrix}$
# B) $\begin{bmatrix}1 & x_1 & x_1^2 & x_1^3 \\
# 1 & x_2 & x_2^2 & x_2^3 \\
# 1 & x_3 & x_3^2 & x_3^3 \\
# \vdots & \vdots & \vdots & \vdots \\
# 1 & x_n & x_n^2 & x_n^3 \end{bmatrix}$
# C) $\begin{bmatrix}1 & x_1 & x_1^2 & x_1^3 & x_1^4 & x_1^5 \\
# 1 & x_2 & x_2^2 & x_2^3 & x_2^4 & x_2^5 \\
# 1 & x_3 & x_3^2 & x_3^3 & x_3^4 & x_3^5 \\
# \vdots & \vdots & \vdots & \vdots & \vdots & \vdots \\
# 1 & x_n & x_n^2 & x_n^3 & x_n^4 & x_n^5 \end{bmatrix}$
# D) $\begin{bmatrix}1 & x_1 & x_1^2 & x_1^4 \\
# 1 & x_2 & x_2^2 & x_2^4 \\
# 1 & x_3 & x_3^2 & x_3^4 \\
# \vdots & \vdots & \vdots & \vdots \\
# 1 & x_n & x_n^2 & x_n^4 \end{bmatrix}$
# **5) How many points are needed to fit an nth order polynomial in polynomial regression?**
# A. n+1
# B. n
# C. 2n
# D. 2n+1
# **6) What is the relationship between the degree of the polynomial and the number of columns in the design matrix X?**
# A. The number of columns in X is equal to the degree of the polynomial.
# B. The number of columns in X is equal to the degree of the polynomial plus one.
# C. The number of columns in X is equal to the square of the degree of the polynomial.
# D. The number of columns in X is equal to the cube of the degree of the polynomial.
# ### 2. Linear independence, span and rank
# The following exercises are aimed at giving you an introduction to linear independence, spand and rank. One of the learning goals with this exercise is to introduce you to some of the core concepts of linear algebra, crucial for understanding the way various machine learning algorithms transform data.
# https://app.grasple.com/#/preview/level/3931/challenge/21318
# https://app.grasple.com/#/preview/level/3931/challenge/21326
# https://app.grasple.com/#/preview/level/3931/challenge/21325
# https://app.grasple.com/#/preview/level/3931/challenge/21320
# https://app.grasple.com/#/preview/level/3931/challenge/21323
# **1.) Is the following set linearly independent?**
# $\begin{bmatrix} 2 & 4 \\
# 0 & 7\end{bmatrix}$
# A) Yes
# B) No
# **2.) Is the following set linearly independent?**
# $\begin{bmatrix} 12 & 15 \\
# -8 & -10\end{bmatrix}$
# A) No
# B) Yes
# **3.) If {x, y} are linearly independent and {x, y, z} are linearly dependent, then z lies in  Span{x, y}.**
# A) True
# B) False
# **4.) Which of the vectors from the set can be removed without changing their span?**
#
# $$\left\{
# \begin{aligned}
#   \boldsymbol{x} &= \begin{bmatrix} 0 \\ -2 \\ 0 \end{bmatrix},
#   \boldsymbol{y} &= \begin{bmatrix} 6 \\ 7 \\ 9 \end{bmatrix},
#   \boldsymbol{z} &= \begin{bmatrix} 0 \\ -8 \\ 0 \end{bmatrix}
# \end{aligned}
# \right\}$$
#
# A) x or y
# B) None
# C) x or z
# D) y
# E) x and z
# **5.) The set $\left\{v_1,v_2,...,v_p\right\}$ of vectors in $R^n$ is said to be linearly dependent if and only if**
# A) There exist nonzero weights $c_1, c_2,..., c_p$ such that $c_1v_1 + c_2v_2 + ... + c_pv_p = 0$
# B) There exist weights $c_1, c_2,..., c_p$, not all zero, such that $c_1v_1 + c_2v_2 + ... + c_pv_p = 0$
# C) The vectors span $R^n$
# D) One of the vectors in the set $\left\{v_1,v_2,...,v_p\right\}$ is a multiple of one of the other vectors.
# E) Not all vectors in the set $\left\{v_1,v_2,...,v_p\right\}$ are distinct.
# ### 3. Basis and projections
# The following exercises are aimed at giving you an introduction to the concepts of basis and projections.
# https://app.grasple.com/#/preview/level/3943/challenge/21548
# https://app.grasple.com/#/preview/level/3944/challenge/21551
# https://app.grasple.com/#/preview/level/3905/challenge/20831
# **1.) What is the geometrical interpretation of a subspace of $R^3$ which has a basis consisting of four vectors?**
# A) This subspace consists of only the zero vector.
# B) This subspace is the empty set.
# C) This subspace is a line.
# D) Such a subspace does not exist.
# E) This subspace is a plane.
# F) This subspace is $R^3$.
# **2.) Determine if the following vectors form a basis for $R^3$**
#
# $$\left\{
# \begin{aligned}
#     \begin{bmatrix} 3 \\ -8 \\ 1 \end{bmatrix},
#     \begin{bmatrix} 6 \\ 2 \\ -5 \end{bmatrix}
# \end{aligned}
# \right\}$$
#
# A) No, a basis for $R^3$ should contain 3 vectors, not 2.
# B) Yes, these vectors are linearly independent and spand $R^3$
# **3.) Compute the orthogonal projection of $\begin{bmatrix} 5 \\ 5 \end{bmatrix}$ onto the line through $\begin{bmatrix} 4 \\ -1 \end{bmatrix}$ and the origin.**
# **4.) If you have a matrix A that represents a linear transformation T with respect to some basis, and you want to find the matrix representation of T with respect to a different basis, what should you do?**
# a) Find the inverse of A
# b) Find the nullspace of A
# c) Multiply A by the change of basis matrix
# d) Add a row of zeros to A
