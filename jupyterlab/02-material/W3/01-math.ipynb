# %%
import requests
from IPython.core.display import HTML
HTML(f"""
<style>
@import "https://cdn.jsdelivr.net/npm/bulma@0.9.4/css/bulma.min.css";
</style>
""")

# %% [markdown]
# # Pen and paper exercises
# These exercises should be completed using only pen and paper. The goal
# is to test some of the basic linear algebra skills needed for proper
# understanding of the course material.
# <article id="props" class="message task">
#     <div class="message-header">
#         <span>Task 1</span>
#         <span class="has-text-right">
#           <i class="bi bi-infinity"></i><i class="bi bi-stoplights medium"></i>
#         </span>
#     </div>
# <div class="message-body">
#
# Determine if the following statements are true or false. If a statement is true, provide an argument. If a statement is false, provide a counterexample:
# 1. If $A^2$ is defined then $A$ is necessarily square.
# 2. If $AB$ and $BA$ are defined then $A$ and $B$ are square.
# 3. If $AB$ and $BA$ are defined then $AB$ and $BA$ are square.
# 4. If $AB=B$ then $A=I$.
#
#
# </div></article>
# <article id="no_inverse" class="message task">
#     <div class="message-header">
#         <span>Task 2</span>
#         <span class="has-text-right">
#           <i class="bi bi-infinity"></i><i class="bi bi-stoplights medium"></i>
#         </span>
#     </div>
# <div class="message-body">
#
# Argue for why a matrix with at least one column of zeroes cannot have an inverse. _Hint: Use linear combinations._
#
# </div></article>
# <article id="transpose_props" class="message task">
#     <div class="message-header">
#         <span>Task 3 <em>(optional)</em></span>
#         <span class="has-text-right">
#           <i class="bi bi-infinity"></i><i class="bi bi-stoplights medium"></i>
#         </span>
#     </div>
# <div class="message-body">
#
# Verify that $(AB)^\top$ equals $B^\top A^\top$ but those are different from $A^\top B^\top$:
#
# $$
# A = \begin{bmatrix}
#    1&0\\
#    2&1
# \end{bmatrix},\quad
# B = \begin{bmatrix}
#    1&3\\
#    0&1
# \end{bmatrix},\quad
# AB = \begin{bmatrix}
#    1&3\\
#    2&7
# \end{bmatrix}
# $$
#
#
# </div></article>
# <article id="eq" class="message task">
#     <div class="message-header">
#         <span>Task 4</span>
#         <span class="has-text-right">
#           <i class="bi bi-infinity"></i><i class="bi bi-stoplights medium"></i>
#         </span>
#     </div>
# <div class="message-body">
#
# 1. Does the equation $(A+B)(A-B)=A^2-B^2$ hold for all square matrices A and B?
# 2. Given the matrix
#
#
# $$
# B=
# \begin{pmatrix}
#    a & b \\
#    c & d
# \end{pmatrix}
# $$
#
# Find conditions on a,b,c and d such that $AB=BA$ where
# (a)
#
# $$
# A=
# \begin{pmatrix}
#    2 & 0 \\
#    0 & 3
# \end{pmatrix}
# $$
#
# (b)
#
# $$
# A=
# \begin{pmatrix}
#    1 & 1 \\
#    0 & 1
# \end{pmatrix}
# $$
#
# (c)
#
# $$
# A=
# \begin{pmatrix}
#    1 & 1 \\
#    1 & 0
# \end{pmatrix}
# $$
#
#
# </div></article>
# <article id="transpose_props" class="message task">
#     <div class="message-header">
#         <span>Task 5</span>
#         <span class="has-text-right">
#           <i class="bi bi-infinity"></i><i class="bi bi-stoplights hard"></i>
#         </span>
#     </div>
# <div class="message-body">
#
# 1. Prove the relation
#
# $$D^{-1}E^{-1}=(ED)^{-1}$$
#
# _hint: Use that the product of a matrix and its inverse is the Identity matrix_
#
#
# 2. Prove the relation
#
# $$(D^{-1})^T=(D^T)^{-1}$$
#
# _hint: Use the property for transposing a product of matrices_
#
#
#
#
# </div></article>
# <article id="col" class="message task">
#     <div class="message-header">
#         <span>Task 6</span>
#         <span class="has-text-right">
#           <i class="bi bi-infinity"></i><i class="bi bi-stoplights medium"></i>
#         </span>
#     </div>
# <div class="message-body">
#
# Given the column vector $\mathbf{v}=\begin{bmatrix}\sqrt{2}\\\sqrt{2}\end{bmatrix}$, create an orthogonal matrix $A$ that has $\mathbf{v}$ as one of its columns:
#
# </div></article>
# <article id="transpose_props" class="message task">
#     <div class="message-header">
#         <span>Task 7</span>
#         <span class="has-text-right">
#           <i class="bi bi-infinity"></i><i class="bi bi-stoplights hard"></i>
#         </span>
#     </div>
# <div class="message-body">
#
# Prove that the following matrix (which describes 2d rotation) is orthogonal:
#
# $$
# \begin{bmatrix}
# \cos{\theta} & -\sin{\theta}\\
# \sin{\theta} & \cos{\theta}
# \end{bmatrix}
# $$
#
#
# </div></article>
# <article id="geom" class="message task">
#     <div class="message-header">
#         <span>Task 8 <em>(optional)</em></span>
#         <span class="has-text-right">
#           <i class="bi bi-infinity"></i><i class="bi bi-stoplights easy"></i>
#         </span>
#     </div>
# <div class="message-body">
#
# Describe geometrically (line, plane or all of $\mathbb{R}^3$) all linear combinations of:
#
# $$
# (a) \quad \begin{bmatrix}1\\2\\3\end{bmatrix} \text{ and } \begin{bmatrix}3\\6\\9\end{bmatrix}
# $$
#
#
# $$
# (a) \quad \begin{bmatrix}1\\0\\0\end{bmatrix} \text{ and } \begin{bmatrix}0\\2\\3\end{bmatrix}
# $$
#
#
# $$
# (a) \quad \begin{bmatrix}2\\0\\0\end{bmatrix} \text{ and } \begin{bmatrix}0\\2\\2\end{bmatrix} \text{ and } \begin{bmatrix}2\\2\\3\end{bmatrix}
# $$
#
#
# </div></article>
# <article id="vectors" class="message task">
#     <div class="message-header">
#         <span>Task 9 <em>(optional)</em></span>
#         <span class="has-text-right">
#           <i class="bi bi-infinity"></i><i class="bi bi-stoplights easy"></i>
#         </span>
#     </div>
# <div class="message-body">
#
# True or false (give a reason if true or find a counterexample if false):
# 1. If $\mathbf{u} = (1, 1, 1)$ is perpendicular to $\mathbf{v}$ and $\mathbf{w}$, then $\mathbf{v}$ is parallel to $\mathbf{w}$.
# 2. If $\mathbf{u}$ is perpendicular to $\mathbf{v}$ and $\mathbf{w}$, then $\mathbf{u}$ is perpendicular to $\mathbf{v}+2\mathbf{w}$.
# 3. If $\mathbf{u}$ and $\mathbf{v}$ are perpendicular unit vectors then $\|\mathbf{u}-\mathbf{v}\| = \sqrt{2}.$
#
#
# </div></article>
# <article id="addition" class="message task">
#     <div class="message-header">
#         <span>Task 10 <em>(optional)</em></span>
#         <span class="has-text-right">
#           <i class="bi bi-infinity"></i><i class="bi bi-stoplights easy"></i>
#         </span>
#     </div>
# <div class="message-body">
#
# Add $AB$ to $AC$ and compare with $A(B+C)$:
#
# $$
# A = \begin{bmatrix}
#    1&5\\
#    2&3
# \end{bmatrix},\quad
# B = \begin{bmatrix}
#    0&2\\
#    0&1
# \end{bmatrix},\quad
# C = \begin{bmatrix}
#    3&1\\
#    0&0
# \end{bmatrix}
# $$
#
#
# </div></article>
