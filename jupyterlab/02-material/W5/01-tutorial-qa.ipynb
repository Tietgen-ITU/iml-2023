# %%
import requests
from IPython.core.display import HTML
HTML(f"""
<style>
@import "https://cdn.jsdelivr.net/npm/bulma@0.9.4/css/bulma.min.css";
</style>
""")

# %% [markdown]
# # Questions for the tutorial
#
# ## Experiments for the tutorial notebook
# The first exercises require you to go back and make changes to the tutorial notebook to better understand the material.
# <article id="project" class="message task">
#     <div class="message-header">
#         <span>Task 1: Projection experiments</span>
#         <span class="has-text-right">
#           <i class="bi bi-stoplights easy"></i>
#         </span>
#     </div>
# <div class="message-body">
#
# 1. Change the points and line (recall Design matrix $A \in  \mathbb{R}^{2 \times 1}$ is called $l$ in the code) and see how it affects the projection:
#
# 2. In the projection section, instead of using the projection matrix on the original points, apply $(A^TA)^{-1}A^T$ to the points and observe the dimensionality of the vectors.
#     - (Optional) Include purely the x-coordinates of the projected points (y-coordinates set to 0) in the plot showcasing the projection.
#
#
#
#
# </div></article>
# <article id="ls" class="message task">
#     <div class="message-header">
#         <span>Task 2: Least squares experiments</span>
#         <span class="has-text-right">
#           <i class="bi bi-stoplights easy"></i>
#         </span>
#     </div>
# <div class="message-body">
#
# 1. In the projection section, apply the projection matrix twice and observe the how it affects the points.
#
# 2. In the least square section, experiment with adding/removing points. What is the minimum number of points required for the method to work and why?
#
# 3. In the least square section, change the values of the points to be futher and closer from the line. How does the $f_{RMS}$ compare with the visual fit of the line? Try exploring different possibilities and write down your observations.
#
#
#
# </div></article>
# ## Pen and paper exercises
# <article id="pmatrix" class="message task">
#     <div class="message-header">
#         <span>Task 3</span>
#         <span class="has-text-right">
#           <i class="bi bi-stoplights medium"></i>
#         </span>
#     </div>
# <div class="message-body">
#
# The projection matrix $P = A(A^\top A )^{-1}A^\top$ is, under certain conditions, equal to the identity matrix.
# 1. Give an example of a design matrix $A$ for which $P=I$.
# 2. Explain why projection matrices are usually not identity matrices.
# 3. (optional) Proove a condition for which $P=I$. Hint: when is $A^\top A=I$?.
#
# (somehow include solutions)
#
# </div></article>
# <article id="function" class="message task">
#     <div class="message-header">
#         <span>Task 4</span>
#         <span class="has-text-right">
#           <i class="bi bi-stoplights easy"></i>
#         </span>
#     </div>
# <div class="message-body">
#
# A matrix $A\in \mathbb{R}^{n\times m}$ can be interpreted as a function. Applying the function to a vector is done through matrix multiplication of the vector $x$, i.e. $y = f(x) = Ax$. Given a model $f_\theta(x) = Ax$ ….
# 1. Write down the equations with knowns/unknowns.
#
# Explain in your own words why line fitting uses the parameters $a, b$ as unknowns/variables.
#
# </div></article>
# <article id="poly" class="message task">
#     <div class="message-header">
#         <span>Task 5</span>
#         <span class="has-text-right">
#           <i class="bi bi-stoplights easy"></i>
#         </span>
#     </div>
# <div class="message-body">
#
# A polynomial is a function of the form $f(x, \theta) = \sum_{i=0}^n \theta_ix^i$, where $\theta$ is a vector of the parameters. For a regular 2d polynomial, this expands to $f(x) = c + bx + ax^2$.
# 1. Identify the knowns and unknowns in the polynomial.
# 2. Explain how to fit a polynomial using least squares (estimate which parameters).
#
#
# </div></article>
